# %% [markdown]
# ![imagem](images/UFSC_Banner.png)

# %% [markdown]
# <div style="font-size: 26px; text-align: center;font-weight: bold">INTRODUÇÃO À DATA ANALYTICS PARA PESQUISA EM CONTABILIDADE</div><br>
#
# <div style="font-size: 22px; text-align: center;font-weight: bold">Projeto: Análise de dados de contratos do Poder Executivo de Santa Catarina</div><br>
#
# <div style="font-size: 20px; text-align: center">JPNB 02 - ETL DOS DADOS DE CONTRATOS</div>

# %% [markdown]
# ---
# <span style='font-size: 14px'>Elaborador por: [Maurício Vasconcellos Leão Lyrio, Dr.](https://br.linkedin.com/in/maur%C3%ADcio-vasconcellos-le%C3%A3o-lyrio-59773220) | Página Oficial: www.vll.adm.br</span>

# %%
# Versão da linguagem Python e arquitetura do Jupyter Notebook
import platform
print('Versão da linguagem Python utilizada neste notebook:', platform.python_version())
print('Arquitetura do Jupyter utilizada neste notebook:', platform.architecture()[0])
# Out:
# Versão da linguagem Python utilizada neste notebook: 3.8.5
# Arquitetura do Jupyter utilizada neste notebook: 64bit

# %% [markdown]
# ---
# # Instalação das bibliotecas

# %%
# Manipulação de dados
import pandas as pd

# Ignorar warnings
import warnings
warnings.filterwarnings('ignore')

# Versões dos pacotes utilizados neste Jupyter notebook
#!pip install -q -U watermark
# %reload_ext watermark
# %watermark -a "Mauricio Vasconcellos Leão Lyrio | vll.adm.br" --iversions
# Out:
# Author: Mauricio Vasconcellos Leão Lyrio | vll.adm.br
#
# pandas  : 1.5.3
# platform: 1.0.8

# %% [markdown]
# ---
# # Carregamento dos datasets

# %% [markdown]
# Os dados de contratos estabelecidos pelo Estado de Santa Catarina foram obtidos do [Portal de Dados Abertos do Estado de Santa Catarina](dados.sc.gov.br). Vamos utilizar dois datasets referentes aos [contratos](https://dados.sc.gov.br/dataset/contratos) firmados pelo Estado:
#
# - Arquivo em formato .csv abrangendo o período entre 2011 e 2021;
# - Arquivo em formato .json abrangendo o ano de 2022.
#
# Em seguida iremos consolidar esses datasets em um único para que possamos fazer nosso trabalho de análise.

# %% [markdown]
# ## Carregando os contratos de 2011 a 2021

# %%
# Carregando o dataset de contratos de 2011 a 2021 a partir do Portal de Dados Abertos (dados.sc.gov.br)
df_2021 = pd.read_csv('https://dados.sc.gov.br/dataset/93dab950-e805-4388-8418-cfb3b73f1623/resource/ac64ba57-bac8-4969-9248-cb9c9b76415d/download/contratos-2011-2021.csv')

# %%
# Verificando se o dataset foi carregado corretamente e seu tipo
type(df_2021)
# Out:
# pandas.core.frame.DataFrame

# %%
# Verificando o formato do dataframe
df_2021.shape
# Out:
# (68752, 55)

# %%
# Listando as colunas do dataframe
df_2021.columns
# Out:
# Index(['ORIGEM', 'CDUNIDADEGESTORA', 'NMUNIDADEGESTORA', 'CDGESTAO',
#        'NMGESTAO', 'NUCONTRATO', 'IDCONTRATADO', 'CONTRATADO', 'RESUMO',
#        'OBJETO', 'DTINIBUSCA', 'DTINICIO', 'DTFIM', 'DTFIMATUAL',
#        'DTASSINATURA', 'SITUACAO', 'NUPROCESSO', 'NUPROCESSOFORMATADO',
#        'VLORIGINAL', 'VLATUAL', 'TAGS', 'NUEDITAL', 'NMBEMPUBLICO',
#        'NMREGIMEEXECUCAO', 'DETIPOCONTRATO', 'DETIPODOCUMENTOLEGAL',
#        'NUDOCUMENTOLEGAL', 'DEMULTA', 'NUAUTORIZACAOORGAO', 'NUPRAZO',
#        'NMINTERVENIENTE', 'NMLOCALEXECUCAO', 'NMMODALIDADE', 'NMREPCREDOR',
#        'NMREPINTERVENIENTE', 'NMREPUG', 'DTAUTORIZACAO', 'DTINCLUSAO',
#        'DTLIMITEPROPOSTA', 'VLGARANTIA', 'VLPERCGARANTIA', 'VLPERCMULTA',
#        'NUTITULO', 'VLADITADO', 'CDUGFISCALIZADOR', 'UGFISCALIZADOR',
#        'CDGESTAOFISCALIZADOR', 'GESTAOFISCALIZADOR', 'BEMPUBLICO',
#        'DEESPTITULO', 'DATAPROPOSTA', 'DIASORIGINAIS', 'DIASADITADOS',
#        'DIASATUAIS', 'INDICE'],
#       dtype='object')

# %% [markdown]
# ## Carregando os contratos de 2022

# %%
# Carregando o dataset de contratos de 2022 a partir do Portal de Dados Abertos (dados.sc.gov.br)
df_2022 = pd.read_json('https://dados.sc.gov.br/dataset/93dab950-e805-4388-8418-cfb3b73f1623/resource/d4a78b11-fd97-4114-8f8b-2bf45ffab0be/download/contratos-2022.json')

# %%
# Verificando se o dataset foi carregado corretamente e seu tipo
type(df_2022)
# Out:
# pandas.core.frame.DataFrame

# %%
# Verificando o formato do dataframe
df_2022.shape
# Out:
# (11788, 57)

# %% [markdown]
# ***Opa!*** o dataset de contratos de 2022 possui duas colunas a mais que o de 2011 a 2021. Qual será a diferença? Vamos verificar ...

# %%
# Listando as colunas do dataframe
df_2022.columns
# Out:
# Index(['ORIGEM', 'CDUNIDADEGESTORA', 'NMUNIDADEGESTORA', 'CDGESTAO',
#        'NMGESTAO', 'NUCONTRATO', 'IDCONTRATADO', 'CONTRATADO', 'RESUMO',
#        'OBJETO', 'DTINIBUSCA', 'DTINICIO', 'DTFIM', 'DTFIMATUAL',
#        'DTASSINATURA', 'SITUACAO', 'NUPROCESSO', 'NUPROCESSOFORMATADO',
#        'VLORIGINAL', 'VLATUAL', 'TAGS', 'NUEDITAL', 'NMBEMPUBLICO',
#        'NMREGIMEEXECUCAO', 'DETIPOCONTRATO', 'DETIPODOCUMENTOLEGAL',
#        'NUDOCUMENTOLEGAL', 'DEMULTA', 'NUAUTORIZACAOORGAO', 'NUPRAZO',
#        'NMINTERVENIENTE', 'NMLOCALEXECUCAO', 'NMMODALIDADE', 'NMREPCREDOR',
#        'NMREPINTERVENIENTE', 'NMREPUG', 'DTAUTORIZACAO', 'DTINCLUSAO',
#        'DTLIMITEPROPOSTA', 'VLGARANTIA', 'VLPERCGARANTIA', 'VLPERCMULTA',
#        'NUTITULO', 'VLADITADO', 'CDUGFISCALIZADOR', 'UGFISCALIZADOR',
#        'CDGESTAOFISCALIZADOR', 'GESTAOFISCALIZADOR', 'BEMPUBLICO',
#        'DEESPTITULO', 'DATAPROPOSTA', 'DIASORIGINAIS', 'DIASADITADOS',
#        'DIASATUAIS', 'INDICE', 'IDCONTRATADOMASCARADO', 'CDCREDOR'],
#       dtype='object')

# %% [markdown]
# Evindenciamos que o **df_2022** possui duas colunas a mais ('IDCONTRATADOMASCARADO', 'CDCREDOR'). Vamos ver o que que é o conteúdo dessas colunas.

# %%
df_2022[['IDCONTRATADO','IDCONTRATADOMASCARADO','CONTRATADO','CDCREDOR']].head()
# Out:
#      IDCONTRATADO IDCONTRATADOMASCARADO  \
# 0  12573088000110    12.573.088/0001-10
# 1  80095425000160    80.095.425/0001-60
# 2  27087458000186    27.087.458/0001-86
# 3  27087458000186    27.087.458/0001-86
# 4  12573088000110    12.573.088/0001-10
#
#                                  CONTRATADO  CDCREDOR
# 0  AR Empreiteira de Mão de Obra Ltda. - ME    368242
# 1                  Azimute Engenharia Ltda.    399414
# 2               Guillherme Raineri de Souza    608832
# 3               Guillherme Raineri de Souza    608832
# 4   AR Execução de Serviços e Comércio LTDa    368242

# %% [markdown]
# A coluna 'IDCONTRATADOMASCARADO' é somente o CNPJ do contratado com a máscara respectiva (que insere os caracteres especiais). A coluna 'CDCREDOR' precisamos confirmar no dicionário de dados o que significa. Lembre-se, o dicionário de dados é seu amigo!

# %% [markdown]
# ## Consolidando os dataframes
#
# No caso do nosso projeto, mesmo sabendo que existem duas colunas a mais no dataframe com os dados de contratos de 2022, iremos concatenar as tabelas para ter uma tabela única que utilizaremos nas próximas fases do trabalho.

# %%
# Concatenando os dois datasets verticalmente em um único dataframe consolidado
df1 = pd.concat([df_2021,df_2022], ignore_index=True)

# %% [markdown]
# ---
# # Análise exploratória dos dados

# %% [markdown]
# Agora que temos um dataframe no qual os dados dos contratos estão consolidados, daremos sequência ao processo de análise, neste ponto iremos verificar a qualidade e integridade dos dados disponíveis.

# %%
# Verificando se o dataframe foi carregado corretamente e seu tipo
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
# Verificando o formato do dataframe
df1.shape
# Out:
# (80540, 57)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80540 entries, 0 to 80539
# Data columns (total 57 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ORIGEM                 80540 non-null  object
#  1   CDUNIDADEGESTORA       80540 non-null  int64
#  2   NMUNIDADEGESTORA       80540 non-null  object
#  3   CDGESTAO               80540 non-null  int64
#  4   NMGESTAO               80540 non-null  object
#  5   NUCONTRATO             80540 non-null  object
#  6   IDCONTRATADO           80540 non-null  int64
#  7   CONTRATADO             80540 non-null  object
#  8   RESUMO                 71121 non-null  object
#  9   OBJETO                 80540 non-null  object
#  10  DTINIBUSCA             80540 non-null  object
#  11  DTINICIO               80393 non-null  object
#  12  DTFIM                  80393 non-null  object
#  13  DTFIMATUAL             80393 non-null  object
#  14  DTASSINATURA           80540 non-null  object
#  15  SITUACAO               80540 non-null  object
#  16  NUPROCESSO             78285 non-null  object
#  17  NUPROCESSOFORMATADO    33644 non-null  object
#  18  VLORIGINAL             80540 non-null  float64
#  19  VLATUAL                80540 non-null  float64
#  20  TAGS                   122 non-null    object
#  21  NUEDITAL               53351 non-null  object
#  22  NMBEMPUBLICO           6231 non-null   object
#  23  NMREGIMEEXECUCAO       24795 non-null  object
#  24  DETIPOCONTRATO         71121 non-null  object
#  25  DETIPODOCUMENTOLEGAL   71121 non-null  object
#  26  NUDOCUMENTOLEGAL       71120 non-null  object
#  27  DEMULTA                612 non-null    object
#  28  NUAUTORIZACAOORGAO     8892 non-null   object
#  29  NUPRAZO                71104 non-null  float64
#  30  NMINTERVENIENTE        2783 non-null   object
#  31  NMLOCALEXECUCAO        71121 non-null  object
#  32  NMMODALIDADE           71121 non-null  object
#  33  NMREPCREDOR            27900 non-null  object
#  34  NMREPINTERVENIENTE     1813 non-null   object
#  35  NMREPUG                27117 non-null  object
#  36  DTAUTORIZACAO          8892 non-null   object
#  37  DTINCLUSAO             71121 non-null  object
#  38  DTLIMITEPROPOSTA       3076 non-null   object
#  39  VLGARANTIA             799 non-null    float64
#  40  VLPERCGARANTIA         799 non-null    float64
#  41  VLPERCMULTA            338 non-null    float64
#  42  NUTITULO               9419 non-null   float64
#  43  VLADITADO              9419 non-null   float64
#  44  CDUGFISCALIZADOR       9419 non-null   float64
#  45  UGFISCALIZADOR         9419 non-null   object
#  46  CDGESTAOFISCALIZADOR   9419 non-null   float64
#  47  GESTAOFISCALIZADOR     9419 non-null   object
#  48  BEMPUBLICO             9419 non-null   object
#  49  DEESPTITULO            9419 non-null   object
#  50  DATAPROPOSTA           9409 non-null   object
#  51  DIASORIGINAIS          6885 non-null   float64
#  52  DIASADITADOS           9272 non-null   float64
#  53  DIASATUAIS             9272 non-null   float64
#  54  INDICE                 80540 non-null  object
#  55  IDCONTRATADOMASCARADO  11788 non-null  object
#  56  CDCREDOR               11788 non-null  float64
# dtypes: float64(14), int64(3), object(40)
# memory usage: 35.0+ MB

# %%
# Configurar o formato desejado de número usando locale
import locale
locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')

# Configurar o formato para evitar notação científica
pd.options.display.float_format = '{:n}'.format

# Configurar opções para exibição completa do DataFrame
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df1.head()
# Out:
#   ORIGEM  CDUNIDADEGESTORA                                   NMUNIDADEGESTORA  \
# 0  SIGEF            540096  Fundo Penitenciário do Estado de Santa Catarin...
# 1  SIGEF            540096  Fundo Penitenciário do Estado de Santa Catarin...
# 2  SIGEF            540096  Fundo Penitenciário do Estado de Santa Catarin...
# 3  SIGEF            540096  Fundo Penitenciário do Estado de Santa Catarin...
# 4  SIGEF            540096  Fundo Penitenciário do Estado de Santa Catarin...
#
#    CDGESTAO                                           NMGESTAO    NUCONTRATO  \
# 0     54096  Fundo Penitenciário do Estado de Santa Catarin...  2018CT013222
# 1     54096  Fundo Penitenciário do Estado de Santa Catarin...  2018CT013223
# 2     54096  Fundo Penitenciário do Estado de Santa Catarin...  2018CT013224
# 3     54096  Fundo Penitenciário do Estado de Santa Catarin...  2018CT013227
# 4     54096  Fundo Penitenciário do Estado de Santa Catarin...  2018CT013228
#
#      IDCONTRATADO                         CONTRATADO  \
# 0  73977480000119            COMERCIAL STORINNY LTDA
# 1   1648513000176         PKB PRODUTOS QUIMICOS LTDA
# 2  83262923000149  DIMAS COMERCIO DE AUTOMOVEIS LTDA
# 3  83262923000149  DIMAS COMERCIO DE AUTOMOVEIS LTDA
# 4  19232159000160  EDENIR DE AQUINO RODRIGUES EIRELI
#
#                                          RESUMO  \
# 0                AQUISIÇÃO DE ARTIGOS SANEANTES
# 1                AQUISIÇÃO DE ARTIGOS SANEANTES
# 2  REVISÃO FORD RANGER PLACA QHV 8196 110.000KM
# 3  REVISÃO FORD RANGER PLACA QHV 8196 110.000KM
# 4                AQUISIÇÃO DE ARTIGOS SANEANTES
#
#                                               OBJETO  DTINIBUSCA    DTINICIO  \
# 0  ATA DE REGISTRO DE PREÇOS VINCULADA AO PREGÃO ...  2018-07-03  2018-07-03
# 1  ATA DE REGISTRO DE PREÇOS VINCULADA AO PREGÃO ...  2018-07-03  2018-07-03
# 2       REVISÃO FORD RANGER PLACA QHV 8196 110.000KM  2018-09-11  2018-09-11
# 3       REVISÃO FORD RANGER PLACA QHV 8196 110.000KM  2018-09-11  2018-09-11
# 4  ATA DE REGISTRO DE PREÇOS VINCULADA AO PREGÃO ...  2018-07-03  2018-07-03
#
#         DTFIM  DTFIMATUAL DTASSINATURA   SITUACAO    NUPROCESSO  \
# 0  2019-07-03  2019-07-03   2018-07-03  Encerrado  ESEJ22693181
# 1  2019-07-03  2019-07-03   2018-07-03  Encerrado  ESEJ22697187
# 2  2018-10-31  2018-10-31   2018-09-11  Encerrado           NaN
# 3  2018-10-31  2018-10-31   2018-09-11  Encerrado           NaN
# 4  2019-07-03  2019-07-03   2018-07-03  Encerrado  ESEJ22686185
#
#   NUPROCESSOFORMATADO  VLORIGINAL  VLATUAL TAGS         NUEDITAL NMBEMPUBLICO  \
# 0                 NaN     259.388        0  NaN  PE 057/SEA/2018          NaN
# 1                 NaN     285.312   73.420  NaN  PE 057/SEA/2018          NaN
# 2                 NaN     1.014,6  1.014,6  NaN              NaN          NaN
# 3                 NaN    1.472,12 1.472,12  NaN              NaN          NaN
# 4                 NaN      70.680   10.080  NaN  PE 057/SEA/2018          NaN
#
#   NMREGIMEEXECUCAO DETIPOCONTRATO      DETIPODOCUMENTOLEGAL  NUDOCUMENTOLEGAL  \
# 0              NaN      Aquisição  Ata de Registro de Preço   PE 057/SEA/2018
# 1              NaN      Aquisição  Ata de Registro de Preço   PE 057/SEA/2018
# 2              NaN      Aquisição  Autorização Fornecimento  PCD/202/SJC/2018
# 3              NaN      Aquisição  Autorização Fornecimento  PCD/202/SJC/2018
# 4              NaN      Aquisição  Ata de Registro de Preço   PE 057/SEA/2018
#
#   DEMULTA NUAUTORIZACAOORGAO  NUPRAZO NMINTERVENIENTE  \
# 0     NaN                NaN      366             NaN
# 1     NaN                NaN      366             NaN
# 2     NaN                NaN       51             NaN
# 3     NaN                NaN       51             NaN
# 4     NaN                NaN      366             NaN
#
#                                      NMLOCALEXECUCAO  \
# 0                     GERÊNCIA DE PATRIMÔNIO - GEPAT
# 1                     GERÊNCIA DE PATRIMÔNIO - GEPAT
# 2  SECRETARIA DE ESTADO DA ADMINISTRAÇÃO PRISIONA...
# 3  SECRETARIA DE ESTADO DA ADMINISTRAÇÃO PRISIONA...
# 4                     GERÊNCIA DE PATRIMÔNIO - GEPAT
#
#                       NMMODALIDADE                   NMREPCREDOR  \
# 0                Pregão Eletrônico  VALTER PLÁCIDO DOS SANTOS JR
# 1                Pregão Eletrônico           GIOVANI KRAMER HORN
# 2  Dispensa de Licitação por Valor                           NaN
# 3  Dispensa de Licitação por Valor                           NaN
# 4                Pregão Eletrônico           ZELI ODETE DA SILVA
#
#   NMREPINTERVENIENTE NMREPUG DTAUTORIZACAO  DTINCLUSAO DTLIMITEPROPOSTA  \
# 0                NaN     NaN           NaN  2019-01-25              NaN
# 1                NaN     NaN           NaN  2018-09-12              NaN
# 2                NaN     NaN           NaN  2018-09-11              NaN
# 3                NaN     NaN           NaN  2018-09-11              NaN
# 4                NaN     NaN           NaN  2019-01-25              NaN
#
#    VLGARANTIA  VLPERCGARANTIA  VLPERCMULTA  NUTITULO  VLADITADO  \
# 0         NaN             NaN          NaN       NaN        NaN
# 1         NaN             NaN          NaN       NaN        NaN
# 2         NaN             NaN          NaN       NaN        NaN
# 3         NaN             NaN          NaN       NaN        NaN
# 4         NaN             NaN          NaN       NaN        NaN
#
#    CDUGFISCALIZADOR UGFISCALIZADOR  CDGESTAOFISCALIZADOR GESTAOFISCALIZADOR  \
# 0               NaN            NaN                   NaN                NaN
# 1               NaN            NaN                   NaN                NaN
# 2               NaN            NaN                   NaN                NaN
# 3               NaN            NaN                   NaN                NaN
# 4               NaN            NaN                   NaN                NaN
#
#   BEMPUBLICO DEESPTITULO DATAPROPOSTA  DIASORIGINAIS  DIASADITADOS  \
# 0        NaN         NaN          NaN            NaN           NaN
# 1        NaN         NaN          NaN            NaN           NaN
# 2        NaN         NaN          NaN            NaN           NaN
# 3        NaN         NaN          NaN            NaN           NaN
# 4        NaN         NaN          NaN            NaN           NaN
#
#    DIASATUAIS                                             INDICE  \
# 0         NaN  SIGEF|540096|FUNDO PENITENCIÁRIO DO ESTADO DE ...
# 1         NaN  SIGEF|540096|FUNDO PENITENCIÁRIO DO ESTADO DE ...
# 2         NaN  SIGEF|540096|FUNDO PENITENCIÁRIO DO ESTADO DE ...
# 3         NaN  SIGEF|540096|FUNDO PENITENCIÁRIO DO ESTADO DE ...
# 4         NaN  SIGEF|540096|FUNDO PENITENCIÁRIO DO ESTADO DE ...
#
#   IDCONTRATADOMASCARADO  CDCREDOR
# 0                   NaN       NaN
# 1                   NaN       NaN
# 2                   NaN       NaN
# 3                   NaN       NaN
# 4                   NaN       NaN

# %% [markdown]
# ---
# # Pré-processamento

# %% [markdown]
# Na fase de análise exploratória identificamos que nosso dataframe possui diversos campos nulos e campos que apesar de estar com tipo numérico, parecem ser informações categóricas. Iremos agora analisar essas questões.

# %% [markdown]
# ## Limpeza

# %% [markdown]
# Conforme visto anteriormente, nosso dataframe possui uma série de campos com valores nulos. Vamos analisar melhor essa situação e definir o que fazer com esses valores. para isso criaremos uma nova **tabela com a distribuição percentual de valores nulos por coluna**.

# %%
# Criando uma lista vazia para armazenar as informações de nome e tipo de coluna.
colunas_info = []

# Iterando pelas colunas do dataframe
for coluna in df1.columns:
    coluna_nome = coluna
    coluna_tipo = df1[coluna].dtype
    coluna_nulos = df1[coluna].isnull().sum()
    coluna_nulos_perc = (coluna_nulos/len(df1))*100
    colunas_info.append((coluna_nome,coluna_tipo,coluna_nulos,coluna_nulos_perc))
                        
# Criando um novo dataframe e exibindo as informações das colunas
df1_colunas_info = pd.DataFrame(colunas_info, columns=['Coluna','Tipo','Q Nulo', '% Nulo'])
print(df1_colunas_info)
# Out:
#                    Coluna     Tipo  Q Nulo   % Nulo
# 0                  ORIGEM   object       0        0
# 1        CDUNIDADEGESTORA    int64       0        0
# 2        NMUNIDADEGESTORA   object       0        0
# 3                CDGESTAO    int64       0        0
# 4                NMGESTAO   object       0        0
# 5              NUCONTRATO   object       0        0
# 6            IDCONTRATADO    int64       0        0
# 7              CONTRATADO   object       0        0
# 8                  RESUMO   object    9419  11,6948
# 9                  OBJETO   object       0        0
# 10             DTINIBUSCA   object       0        0
# 11               DTINICIO   object     147 0,182518
# 12                  DTFIM   object     147 0,182518
# 13             DTFIMATUAL   object     147 0,182518
# 14           DTASSINATURA   object       0        0
# 15               SITUACAO   object       0        0
# 16             NUPROCESSO   object    2255  2,79985
# 17    NUPROCESSOFORMATADO   object   46896   58,227
# 18             VLORIGINAL  float64       0        0
# 19                VLATUAL  float64       0        0
# 20                   TAGS   object   80418  99,8485
# 21               NUEDITAL   object   27189  33,7584
# 22           NMBEMPUBLICO   object   74309  92,2635
# 23       NMREGIMEEXECUCAO   object   55745  69,2141
# 24         DETIPOCONTRATO   object    9419  11,6948
# 25   DETIPODOCUMENTOLEGAL   object    9419  11,6948
# 26       NUDOCUMENTOLEGAL   object    9420  11,6961
# 27                DEMULTA   object   79928  99,2401
# 28     NUAUTORIZACAOORGAO   object   71648  88,9595
# 29                NUPRAZO  float64    9436  11,7159
# 30        NMINTERVENIENTE   object   77757  96,5446
# 31        NMLOCALEXECUCAO   object    9419  11,6948
# 32           NMMODALIDADE   object    9419  11,6948
# 33            NMREPCREDOR   object   52640  65,3588
# 34     NMREPINTERVENIENTE   object   78727  97,7489
# 35                NMREPUG   object   53423   66,331
# 36          DTAUTORIZACAO   object   71648  88,9595
# 37             DTINCLUSAO   object    9419  11,6948
# 38       DTLIMITEPROPOSTA   object   77464  96,1808
# 39             VLGARANTIA  float64   79741  99,0079
# 40         VLPERCGARANTIA  float64   79741  99,0079
# 41            VLPERCMULTA  float64   80202  99,5803
# 42               NUTITULO  float64   71121  88,3052
# 43              VLADITADO  float64   71121  88,3052
# 44       CDUGFISCALIZADOR  float64   71121  88,3052
# 45         UGFISCALIZADOR   object   71121  88,3052
# 46   CDGESTAOFISCALIZADOR  float64   71121  88,3052
# 47     GESTAOFISCALIZADOR   object   71121  88,3052
# 48             BEMPUBLICO   object   71121  88,3052
# 49            DEESPTITULO   object   71121  88,3052
# 50           DATAPROPOSTA   object   71131  88,3176
# 51          DIASORIGINAIS  float64   73655  91,4515
# 52           DIASADITADOS  float64   71268  88,4877
# 53             DIASATUAIS  float64   71268  88,4877
# 54                 INDICE   object       0        0
# 55  IDCONTRATADOMASCARADO   object   68752  85,3638
# 56               CDCREDOR  float64   68752  85,3638

# %% [markdown]
# Com a nova tabela fica mais fácil evidenciar os valores ausentes do dataframe. Em projetos de datascience, em geral, utiliza-se como regra para tratamento de valores ausentes as seguintes opções:
#
# - Para valores ausentes < 2%, descartar os valores ausentes;
# - Para valores ausentes >= 50%, descartamos a variável;
# - Para valores ausentes < 50%, tratar os valores ausentes.

# %% [markdown]
# > ***Momento de decisão!*** O que iremos fazer com os valores nulos?

# %% [markdown]
# Antes de começar, vamos fazer uma cópia do nosso dataframe original para não perder o histórico das informações.

# %%
df2 = df1.copy()

# %% [markdown]
# > ***O que faremos com os valore nulos que representam - de 2% dos registros em uma determinada coluna?*** Vamos pensar que cada registro é um contrato firmado e, caso optemos por excluí-lo, estaremos excluindo um contrato de nossa base de dados.

# %%
# Caso optemos por excluir os registros < 2% nulos:
#df2 = df2.dropna(subset=['DTINICIO'])    # 0,18% dos registros são nulos
#df2 = df2.dropna(subset=['DTFIM'])    # 0,18% dos registros são nulos
#df2 = df2.dropna(subset=['DTFIMATUAL'])    # 0,18% dos registros são nulos
#df2 = df2.dropna(subset=['NUPROCESSO'])    # 2,80% dos registros são nulos

#df2.isnull().sum()

# %% [markdown]
# > ***O que faremos com as colunas nas quais os registros nulos representam mais de 50% dos registros?*** Lembrando sempre que ao excluir uma linha estamos excluindo um contrato e ao excluir uma coluna estamos excluindo uma informação (atributo) de todos os contratos da amostra.

# %% [markdown]
# Analisando os valores nulos de cada coluna vamos definindo se iremos ou não excluí-la. Por exemplo, podemos manter as colunas que estão com 88.28% de valores nulos dado que a primeira vista se constiem nos contratos de obras advindos do sistema SICOP, caso dropemos essas colunas perderemos a informação referente a isso.

# %%
# Excluindo as colunas que não iremos utilizar
df2 = df2.drop(columns=['NUPROCESSOFORMATADO',
                        'TAGS',
                        'NMBEMPUBLICO',
                        'NMREGIMEEXECUCAO',
                        'DEMULTA',
                        'NUAUTORIZACAOORGAO',
                        'NMINTERVENIENTE',
                        'NMREPUG',
                        'DTAUTORIZACAO',
                        'DTLIMITEPROPOSTA',
                        'VLGARANTIA',
                        'VLPERCMULTA',
                        'DATAPROPOSTA',
                        'DIASORIGINAIS',
                        'DIASADITADOS',
                        'DIASATUAIS',
                        'IDCONTRATADOMASCARADO',
                        'CDCREDOR'
                       ])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80540 entries, 0 to 80539
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORIGEM                80540 non-null  object
#  1   CDUNIDADEGESTORA      80540 non-null  int64
#  2   NMUNIDADEGESTORA      80540 non-null  object
#  3   CDGESTAO              80540 non-null  int64
#  4   NMGESTAO              80540 non-null  object
#  5   NUCONTRATO            80540 non-null  object
#  6   IDCONTRATADO          80540 non-null  int64
#  7   CONTRATADO            80540 non-null  object
#  8   RESUMO                71121 non-null  object
#  9   OBJETO                80540 non-null  object
#  10  DTINIBUSCA            80540 non-null  object
#  11  DTINICIO              80393 non-null  object
#  12  DTFIM                 80393 non-null  object
#  13  DTFIMATUAL            80393 non-null  object
#  14  DTASSINATURA          80540 non-null  object
#  15  SITUACAO              80540 non-null  object
#  16  NUPROCESSO            78285 non-null  object
#  17  VLORIGINAL            80540 non-null  float64
#  18  VLATUAL               80540 non-null  float64
#  19  NUEDITAL              53351 non-null  object
#  20  DETIPOCONTRATO        71121 non-null  object
#  21  DETIPODOCUMENTOLEGAL  71121 non-null  object
#  22  NUDOCUMENTOLEGAL      71120 non-null  object
#  23  NUPRAZO               71104 non-null  float64
#  24  NMLOCALEXECUCAO       71121 non-null  object
#  25  NMMODALIDADE          71121 non-null  object
#  26  NMREPCREDOR           27900 non-null  object
#  27  NMREPINTERVENIENTE    1813 non-null   object
#  28  DTINCLUSAO            71121 non-null  object
#  29  VLPERCGARANTIA        799 non-null    float64
#  30  NUTITULO              9419 non-null   float64
#  31  VLADITADO             9419 non-null   float64
#  32  CDUGFISCALIZADOR      9419 non-null   float64
#  33  UGFISCALIZADOR        9419 non-null   object
#  34  CDGESTAOFISCALIZADOR  9419 non-null   float64
#  35  GESTAOFISCALIZADOR    9419 non-null   object
#  36  BEMPUBLICO            9419 non-null   object
#  37  DEESPTITULO           9419 non-null   object
#  38  INDICE                80540 non-null  object
# dtypes: float64(8), int64(3), object(28)
# memory usage: 24.0+ MB

# %% [markdown]
# ## Transformação

# %% [markdown]
# Iniciaremos a etapa de transformação de dados fazendo o ***preenchimento dos campos com registros nulos*** em nosso dataframe.

# %%
# Preenchendo os valores nulos das colunas de data e número com valores padronizados
df2['DTINICIO'].fillna('1900-01-01', inplace=True)
df2['DTFIM'].fillna('1900-01-01', inplace=True)
df2['DTFIMATUAL'].fillna('1900-01-01', inplace=True)
df2['DTINCLUSAO'].fillna('1900-01-01', inplace=True)
df2['VLPERCGARANTIA'].fillna(0, inplace=True)
df2['VLADITADO'].fillna(0, inplace=True)

df2.isnull().sum()
# Out:
# ORIGEM                      0
# CDUNIDADEGESTORA            0
# NMUNIDADEGESTORA            0
# CDGESTAO                    0
# NMGESTAO                    0
# NUCONTRATO                  0
# IDCONTRATADO                0
# CONTRATADO                  0
# RESUMO                   9419
# OBJETO                      0
# DTINIBUSCA                  0
# DTINICIO                    0
# DTFIM                       0
# DTFIMATUAL                  0
# DTASSINATURA                0
# SITUACAO                    0
# NUPROCESSO               2255
# VLORIGINAL                  0
# VLATUAL                     0
# NUEDITAL                27189
# DETIPOCONTRATO           9419
# DETIPODOCUMENTOLEGAL     9419
# NUDOCUMENTOLEGAL         9420
# NUPRAZO                  9436
# NMLOCALEXECUCAO          9419
# NMMODALIDADE             9419
# NMREPCREDOR             52640
# NMREPINTERVENIENTE      78727
# DTINCLUSAO                  0
# VLPERCGARANTIA              0
# NUTITULO                71121
# VLADITADO                   0
# CDUGFISCALIZADOR        71121
# UGFISCALIZADOR          71121
# CDGESTAOFISCALIZADOR    71121
# GESTAOFISCALIZADOR      71121
# BEMPUBLICO              71121
# DEESPTITULO             71121
# INDICE                      0
# dtype: int64

# %%
# Criando uma lista com os demais campos com valores nulos
colunas_com_nulos = df2.columns[df2.isnull().any()].tolist()

# Alterando o tipo de dado das colunas com valores nulos para object
df2[colunas_com_nulos] = df2[colunas_com_nulos].astype(object)

# Preenchendo os valores nulos com o termo 'Não definido'
df2.fillna('Não definido',inplace=True)

# %%
df2.isnull().sum()
# Out:
# ORIGEM                  0
# CDUNIDADEGESTORA        0
# NMUNIDADEGESTORA        0
# CDGESTAO                0
# NMGESTAO                0
# NUCONTRATO              0
# IDCONTRATADO            0
# CONTRATADO              0
# RESUMO                  0
# OBJETO                  0
# DTINIBUSCA              0
# DTINICIO                0
# DTFIM                   0
# DTFIMATUAL              0
# DTASSINATURA            0
# SITUACAO                0
# NUPROCESSO              0
# VLORIGINAL              0
# VLATUAL                 0
# NUEDITAL                0
# DETIPOCONTRATO          0
# DETIPODOCUMENTOLEGAL    0
# NUDOCUMENTOLEGAL        0
# NUPRAZO                 0
# NMLOCALEXECUCAO         0
# NMMODALIDADE            0
# NMREPCREDOR             0
# NMREPINTERVENIENTE      0
# DTINCLUSAO              0
# VLPERCGARANTIA          0
# NUTITULO                0
# VLADITADO               0
# CDUGFISCALIZADOR        0
# UGFISCALIZADOR          0
# CDGESTAOFISCALIZADOR    0
# GESTAOFISCALIZADOR      0
# BEMPUBLICO              0
# DEESPTITULO             0
# INDICE                  0
# dtype: int64

# %%
# Alterando o tipo colunas  CDUNIDADEGESTORA, CDGESTAO, e IDCONTRATADO para object.
df2[['CDUNIDADEGESTORA', 'CDGESTAO', 'IDCONTRATADO']] = df2[['CDUNIDADEGESTORA', 'CDGESTAO', 'IDCONTRATADO']].astype(object)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80540 entries, 0 to 80539
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORIGEM                80540 non-null  object
#  1   CDUNIDADEGESTORA      80540 non-null  object
#  2   NMUNIDADEGESTORA      80540 non-null  object
#  3   CDGESTAO              80540 non-null  object
#  4   NMGESTAO              80540 non-null  object
#  5   NUCONTRATO            80540 non-null  object
#  6   IDCONTRATADO          80540 non-null  object
#  7   CONTRATADO            80540 non-null  object
#  8   RESUMO                80540 non-null  object
#  9   OBJETO                80540 non-null  object
#  10  DTINIBUSCA            80540 non-null  object
#  11  DTINICIO              80540 non-null  object
#  12  DTFIM                 80540 non-null  object
#  13  DTFIMATUAL            80540 non-null  object
#  14  DTASSINATURA          80540 non-null  object
#  15  SITUACAO              80540 non-null  object
#  16  NUPROCESSO            80540 non-null  object
#  17  VLORIGINAL            80540 non-null  float64
#  18  VLATUAL               80540 non-null  float64
#  19  NUEDITAL              80540 non-null  object
#  20  DETIPOCONTRATO        80540 non-null  object
#  21  DETIPODOCUMENTOLEGAL  80540 non-null  object
#  22  NUDOCUMENTOLEGAL      80540 non-null  object
#  23  NUPRAZO               80540 non-null  object
#  24  NMLOCALEXECUCAO       80540 non-null  object
#  25  NMMODALIDADE          80540 non-null  object
#  26  NMREPCREDOR           80540 non-null  object
#  27  NMREPINTERVENIENTE    80540 non-null  object
#  28  DTINCLUSAO            80540 non-null  object
#  29  VLPERCGARANTIA        80540 non-null  float64
#  30  NUTITULO              80540 non-null  object
#  31  VLADITADO             80540 non-null  float64
#  32  CDUGFISCALIZADOR      80540 non-null  object
#  33  UGFISCALIZADOR        80540 non-null  object
#  34  CDGESTAOFISCALIZADOR  80540 non-null  object
#  35  GESTAOFISCALIZADOR    80540 non-null  object
#  36  BEMPUBLICO            80540 non-null  object
#  37  DEESPTITULO           80540 non-null  object
#  38  INDICE                80540 non-null  object
# dtypes: float64(4), object(35)
# memory usage: 24.0+ MB

# %%
# criando uma lista com as colunas de data
colunas_data = ['DTINIBUSCA', 'DTINICIO', 'DTFIM', 'DTFIMATUAL', 'DTASSINATURA', 'DTINCLUSAO']

# Convertendo as colunas de data para o formato ano-mes-dia
df2[colunas_data] = df2[colunas_data].astype('datetime64[ns]')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80540 entries, 0 to 80539
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORIGEM                80540 non-null  object
#  1   CDUNIDADEGESTORA      80540 non-null  object
#  2   NMUNIDADEGESTORA      80540 non-null  object
#  3   CDGESTAO              80540 non-null  object
#  4   NMGESTAO              80540 non-null  object
#  5   NUCONTRATO            80540 non-null  object
#  6   IDCONTRATADO          80540 non-null  object
#  7   CONTRATADO            80540 non-null  object
#  8   RESUMO                80540 non-null  object
#  9   OBJETO                80540 non-null  object
#  10  DTINIBUSCA            80540 non-null  datetime64[ns]
#  11  DTINICIO              80540 non-null  datetime64[ns]
#  12  DTFIM                 80540 non-null  datetime64[ns]
#  13  DTFIMATUAL            80540 non-null  datetime64[ns]
#  14  DTASSINATURA          80540 non-null  datetime64[ns]
#  15  SITUACAO              80540 non-null  object
#  16  NUPROCESSO            80540 non-null  object
#  17  VLORIGINAL            80540 non-null  float64
#  18  VLATUAL               80540 non-null  float64
#  19  NUEDITAL              80540 non-null  object
#  20  DETIPOCONTRATO        80540 non-null  object
#  21  DETIPODOCUMENTOLEGAL  80540 non-null  object
#  22  NUDOCUMENTOLEGAL      80540 non-null  object
#  23  NUPRAZO               80540 non-null  object
#  24  NMLOCALEXECUCAO       80540 non-null  object
#  25  NMMODALIDADE          80540 non-null  object
#  26  NMREPCREDOR           80540 non-null  object
#  27  NMREPINTERVENIENTE    80540 non-null  object
#  28  DTINCLUSAO            80540 non-null  datetime64[ns]
#  29  VLPERCGARANTIA        80540 non-null  float64
#  30  NUTITULO              80540 non-null  object
#  31  VLADITADO             80540 non-null  float64
#  32  CDUGFISCALIZADOR      80540 non-null  object
#  33  UGFISCALIZADOR        80540 non-null  object
#  34  CDGESTAOFISCALIZADOR  80540 non-null  object
#  35  GESTAOFISCALIZADOR    80540 non-null  object
#  36  BEMPUBLICO            80540 non-null  object
#  37  DEESPTITULO           80540 non-null  object
#  38  INDICE                80540 non-null  object
# dtypes: datetime64[ns](6), float64(4), object(29)
# memory usage: 24.0+ MB

# %% [markdown]
# Por fim, vamos configurar o campo IDCONTRATADO para que os registros fique no ***padrão de CNPJ***.

# %%
# Formatando os valores do campo de CNPJ (IDCONTRATADO)
for i, cnpj in enumerate(df2['IDCONTRATADO']):
    # Convertendo para string antes de verificar o comprimento
    cnpj_str = str(cnpj)
    # se o registro tiver menos de 14 caracteres
    if len(cnpj_str) < 14:
        # Incluir '0' no início até que o registro tenha 14 caracteres
        df2.at[i, 'IDCONTRATADO'] = '0' * (14 - len(cnpj_str)) + cnpj_str
        
# Criando uma máscara de CNPJ para o campo 'IDCONTRATADO'
df2['IDCONTRATADO'] = df2['IDCONTRATADO'].astype(str).apply(lambda x: f'{x[:2]}.{x[2:5]}.{x[5:8]}/{x[8:12]}-{x[12:]}')

# %% [markdown]
# Com a finalização do processo de tranformação de dados nosso dataframe está pronto para ser carregado em banco de dados ou exportado em formatos de arquivos para análise posterior. É o que iremos fazer agora, na fazer de geração de dados de saída.

# %%
# Descrevendo os dados numéricos (selecionadas apenas as colunas que realmente se constituem em dados numéricos)
df2.describe()
# Out:
#        VLORIGINAL      VLATUAL  VLPERCGARANTIA   VLADITADO
# count      80.540       80.540          80.540      80.540
# mean      788.990 -3,15493e+07        0,779805      13.924
# std   8,35599e+07  9,09573e+09         8,73663     488.087
# min          0,01 -2,58133e+12               0    -5,7e+07
# 25%      5.324,44     3.195,61               0           0
# 50%      21.513,2       16.424               0           0
# 75%       100.000     86.674,6               0           0
# max   2,36022e+10  1,52652e+09             100 7,66365e+07

# %%
# Descrevendo os dados não numéricos
df2.describe(include=object)
# Out:
#        ORIGEM  CDUNIDADEGESTORA  \
# count   80540             80540
# unique      2               169
# top     SIGEF            160097
# freq    71121             13999
#
#                                          NMUNIDADEGESTORA  CDGESTAO  \
# count                                               80540     80540
# unique                                                280        30
# top     Fundo de Melhoria da Polícia Militar          ...         1
# freq                                                13523     41715
#
#                                                  NMGESTAO    NUCONTRATO  \
# count                                               80540         80540
# unique                                                 47         80533
# top     Gestão Geral                                  ...  2015CT002473
# freq                                                33717             2
#
#               IDCONTRATADO          CONTRATADO        RESUMO  \
# count                80540               80540         80540
# unique               12279               12518         26024
# top     83.043.745/0001-65  STANG   STANG LTDA  Não definido
# freq                   780                1144          9419
#
#                                                    OBJETO   SITUACAO  \
# count                                               80540      80540
# unique                                              53389         18
# top     Contratação de empresa para fornecimento de co...  Encerrado
# freq                                                 1558      56070
#
#        NUPROCESSO      NUEDITAL DETIPOCONTRATO DETIPODOCUMENTOLEGAL  \
# count       80540         80540          80540                80540
# unique      40230         19463              5                    4
# top                Não definido      Aquisição             Contrato
# freq         6216         27189          45330                49907
#
#        NUDOCUMENTOLEGAL  NUPRAZO                              NMLOCALEXECUCAO  \
# count             80540   80.540                                        80540
# unique            43984    1.459                                         1602
# top        Não definido      365  Fundo de Melhoria da Polícia Militar FUMPOM
# freq               9420   10.410                                        12670
#
#              NMMODALIDADE   NMREPCREDOR NMREPINTERVENIENTE      NUTITULO  \
# count               80540         80540              80540         80540
# unique                 13         10336                881          9415
# top     Pregão Eletrônico  Não definido       Não definido  Não definido
# freq                31276         52640              78727         71121
#
#        CDUGFISCALIZADOR UGFISCALIZADOR CDGESTAOFISCALIZADOR  \
# count             80540          80540                80540
# unique               84             88                   12
# top        Não definido   Não definido         Não definido
# freq              71121          71121                71121
#
#        GESTAOFISCALIZADOR    BEMPUBLICO   DEESPTITULO  \
# count               80540         80540         80540
# unique                 13          3149            11
# top          Não definido  Não definido  Não definido
# freq                71121         71121         71121
#
#                                                    INDICE
# count                                               80540
# unique                                              80540
# top     SIGEF|540096|FUNDO PENITENCIÁRIO DO ESTADO DE ...
# freq                                                    1

# %%
df2.head()
# Out:
#   ORIGEM CDUNIDADEGESTORA                                   NMUNIDADEGESTORA  \
# 0  SIGEF           540096  Fundo Penitenciário do Estado de Santa Catarin...
# 1  SIGEF           540096  Fundo Penitenciário do Estado de Santa Catarin...
# 2  SIGEF           540096  Fundo Penitenciário do Estado de Santa Catarin...
# 3  SIGEF           540096  Fundo Penitenciário do Estado de Santa Catarin...
# 4  SIGEF           540096  Fundo Penitenciário do Estado de Santa Catarin...
#
#   CDGESTAO                                           NMGESTAO    NUCONTRATO  \
# 0    54096  Fundo Penitenciário do Estado de Santa Catarin...  2018CT013222
# 1    54096  Fundo Penitenciário do Estado de Santa Catarin...  2018CT013223
# 2    54096  Fundo Penitenciário do Estado de Santa Catarin...  2018CT013224
# 3    54096  Fundo Penitenciário do Estado de Santa Catarin...  2018CT013227
# 4    54096  Fundo Penitenciário do Estado de Santa Catarin...  2018CT013228
#
#          IDCONTRATADO                         CONTRATADO  \
# 0  73.977.480/0001-19            COMERCIAL STORINNY LTDA
# 1  01.648.513/0001-76         PKB PRODUTOS QUIMICOS LTDA
# 2  83.262.923/0001-49  DIMAS COMERCIO DE AUTOMOVEIS LTDA
# 3  83.262.923/0001-49  DIMAS COMERCIO DE AUTOMOVEIS LTDA
# 4  19.232.159/0001-60  EDENIR DE AQUINO RODRIGUES EIRELI
#
#                                          RESUMO  \
# 0                AQUISIÇÃO DE ARTIGOS SANEANTES
# 1                AQUISIÇÃO DE ARTIGOS SANEANTES
# 2  REVISÃO FORD RANGER PLACA QHV 8196 110.000KM
# 3  REVISÃO FORD RANGER PLACA QHV 8196 110.000KM
# 4                AQUISIÇÃO DE ARTIGOS SANEANTES
#
#                                               OBJETO DTINIBUSCA   DTINICIO  \
# 0  ATA DE REGISTRO DE PREÇOS VINCULADA AO PREGÃO ... 2018-07-03 2018-07-03
# 1  ATA DE REGISTRO DE PREÇOS VINCULADA AO PREGÃO ... 2018-07-03 2018-07-03
# 2       REVISÃO FORD RANGER PLACA QHV 8196 110.000KM 2018-09-11 2018-09-11
# 3       REVISÃO FORD RANGER PLACA QHV 8196 110.000KM 2018-09-11 2018-09-11
# 4  ATA DE REGISTRO DE PREÇOS VINCULADA AO PREGÃO ... 2018-07-03 2018-07-03
#
#        DTFIM DTFIMATUAL DTASSINATURA   SITUACAO    NUPROCESSO  VLORIGINAL  \
# 0 2019-07-03 2019-07-03   2018-07-03  Encerrado  ESEJ22693181     259.388
# 1 2019-07-03 2019-07-03   2018-07-03  Encerrado  ESEJ22697187     285.312
# 2 2018-10-31 2018-10-31   2018-09-11  Encerrado  Não definido     1.014,6
# 3 2018-10-31 2018-10-31   2018-09-11  Encerrado  Não definido    1.472,12
# 4 2019-07-03 2019-07-03   2018-07-03  Encerrado  ESEJ22686185      70.680
#
#    VLATUAL         NUEDITAL DETIPOCONTRATO      DETIPODOCUMENTOLEGAL  \
# 0        0  PE 057/SEA/2018      Aquisição  Ata de Registro de Preço
# 1   73.420  PE 057/SEA/2018      Aquisição  Ata de Registro de Preço
# 2  1.014,6     Não definido      Aquisição  Autorização Fornecimento
# 3 1.472,12     Não definido      Aquisição  Autorização Fornecimento
# 4   10.080  PE 057/SEA/2018      Aquisição  Ata de Registro de Preço
#
#    NUDOCUMENTOLEGAL NUPRAZO  \
# 0   PE 057/SEA/2018     366
# 1   PE 057/SEA/2018     366
# 2  PCD/202/SJC/2018      51
# 3  PCD/202/SJC/2018      51
# 4   PE 057/SEA/2018     366
#
#                                      NMLOCALEXECUCAO  \
# 0                     GERÊNCIA DE PATRIMÔNIO - GEPAT
# 1                     GERÊNCIA DE PATRIMÔNIO - GEPAT
# 2  SECRETARIA DE ESTADO DA ADMINISTRAÇÃO PRISIONA...
# 3  SECRETARIA DE ESTADO DA ADMINISTRAÇÃO PRISIONA...
# 4                     GERÊNCIA DE PATRIMÔNIO - GEPAT
#
#                       NMMODALIDADE                   NMREPCREDOR  \
# 0                Pregão Eletrônico  VALTER PLÁCIDO DOS SANTOS JR
# 1                Pregão Eletrônico           GIOVANI KRAMER HORN
# 2  Dispensa de Licitação por Valor                  Não definido
# 3  Dispensa de Licitação por Valor                  Não definido
# 4                Pregão Eletrônico           ZELI ODETE DA SILVA
#
#   NMREPINTERVENIENTE DTINCLUSAO  VLPERCGARANTIA      NUTITULO  VLADITADO  \
# 0       Não definido 2019-01-25               0  Não definido          0
# 1       Não definido 2018-09-12               0  Não definido          0
# 2       Não definido 2018-09-11               0  Não definido          0
# 3       Não definido 2018-09-11               0  Não definido          0
# 4       Não definido 2019-01-25               0  Não definido          0
#
#   CDUGFISCALIZADOR UGFISCALIZADOR CDGESTAOFISCALIZADOR GESTAOFISCALIZADOR  \
# 0     Não definido   Não definido         Não definido       Não definido
# 1     Não definido   Não definido         Não definido       Não definido
# 2     Não definido   Não definido         Não definido       Não definido
# 3     Não definido   Não definido         Não definido       Não definido
# 4     Não definido   Não definido         Não definido       Não definido
#
#      BEMPUBLICO   DEESPTITULO  \
# 0  Não definido  Não definido
# 1  Não definido  Não definido
# 2  Não definido  Não definido
# 3  Não definido  Não definido
# 4  Não definido  Não definido
#
#                                               INDICE
# 0  SIGEF|540096|FUNDO PENITENCIÁRIO DO ESTADO DE ...
# 1  SIGEF|540096|FUNDO PENITENCIÁRIO DO ESTADO DE ...
# 2  SIGEF|540096|FUNDO PENITENCIÁRIO DO ESTADO DE ...
# 3  SIGEF|540096|FUNDO PENITENCIÁRIO DO ESTADO DE ...
# 4  SIGEF|540096|FUNDO PENITENCIÁRIO DO ESTADO DE ...

# %% [markdown]
# ---
# # Geração de dados de saída (Data output)

# %% [markdown]
# Uma vez finalizada a fase de limpeza e transformação, agora iremos dar saída ao dataset gerado para fins de análise. Faremos isso em forma de arquivos e em registros em banco de dados.

# %% [markdown]
# ## Gravação em arquivos

# %%
# Gravando em formato .csv
df2.to_csv('datasets/df2_contratos.csv',index=False)

# Gravando em formato .json
# df2.to_json('datasets/df2_contratos.json')

# Gravando em formato .xls
# df2.to_excel('datasets/df2_contratos.xlsx',index=False)

# %% [markdown]
# ## Gravação em DB relacional

# %% [markdown]
# > Gravando em banco de dados SQLite

# %%
# Importando a biblioteca sqlite3
import sqlite3

# Criando uma conexão ao banco de dados SQLite
cnn=sqlite3.connect('database/bdContratosSC.db')

# Copiando nosso dataframe para o banco de dados
df2.to_sql('Contratos',cnn)
# Out:
# 80540

# %% [markdown]
# > Abaixo o código para gravação em banco de dados ***MySQL***, não executaremos esse script porque necessitamos ter  SGBD instalado.

# %%
# Importando a biblioteca para interação com o MySQL
#import mysql.connector

# Configurando os parâmetros da conexão
#config={
#    'user':'seu usuário';
#    'password':'sua_senha';
#    'host':'https';    # ou endereço do servidor MySQL
#    'database':'seu_bando_de_dados'
#}

# Criando uma conexão ao banco de dados
#try:
#    conn=mysql.connector.connect(**config)
#    if conn.is_connected():
#        print('Conexão ao banco de dados bem sucedida')
#except mysql.connector.Error as err:
#    print(f'Erro ao conectar ao banco de dados: {err}')

# Copiando nosso dataframe para o banco de dados

# Fechando a conexão (ao terminar de utilizar)
#conn.close()

# %% [markdown]
# ## Gravação em datalake (BD não-relacional)

# %% [markdown]
# > Abaixo o código para gravação em banco de dados ***MongoDB***, não executaremos esse script porque necessitamos ter  SGBD instalado.

# %%
# Importando a biblioteca para interação com o MongoDB
#from pymongo import MongoClient

# Configurando os parâmetros de conexão
#client=MongoClient('mongodb://localhost:27017/')

# Acessando um banco de dados específico
#db=client['appdb']

# Criando uma coleção no banco de dados
#collection = db['Contratos']

# Carregando o dataframe
#data = df2.to_dict(orient='records')

# Inserindo os registros no MongoDB
#collection.insert_many(data)

# Listando as coleções disponíveis
#print(db.list_collection_names())

# %%
#contratos=collection.find()
#for contrato in contratos:
#    print(contrato)

# %%
# Fechando a conexão ao MongoDB
#client.close()

# %% [markdown]
# Com a geração dos dados de saída, nosso trabalho de ***ETL*** de dados terminou. Fizemos a limpeza, transformação e carga de dados para arquivos de saíde e bancos de dados relacionais e não-relacionais. Agora passaremos à etapa de visualização de dados (dataviz) que faremos utilizando o Microsoft Power BI como ferramenta.

# %% [markdown]
# ---

# %% [markdown]
# <div style="font-size: 32px; text-align: center;font-weight: bold">FIM</div>
